# %% [markdown]
# # --- Non-linear dataset (swiss roll) -----------------------------------------------------------

# %% [markdown]
# ## Populate swiss-roll dataset

# %%
from sklearn import datasets

# %%
X, color = datasets.make_swiss_roll(n_samples=5000, noise=0.0)

# %%
Y_labels = ['X', 'Y', 'Z']

# %% [markdown]
# ## Prepare data (feature scaling)

# %%
#from sklearn import preprocessing

# %%
#std_scale = preprocessing.StandardScaler().fit(X)

# %%
#X_scaled = std_scale.transform(X)
X_scaled = X

# %% [markdown]
# ## Apply t-SNE dimentionality reduction

# %%
from sklearn import decomposition
kpca = decomposition.KernelPCA(n_components=2, kernel='rbf', gamma=0.1) # linear, rbf, poly, sigmoid, cosine

# %%
from time import time

# %%
t0 = time()
X_projected_kpca = kpca.fit_transform(X_scaled)
t1 = time()

# %%
print("Time:", t1-t0)
# Out:
# Time: 1.6816790103912354

# %% [markdown]
# ## Plot

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(17,5))

ax = fig.add_subplot(131, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.Spectral)
ax.set_title("Original data")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax = fig.add_subplot(132)
ax.scatter(X_projected_kpca[:, 0], X_projected_kpca[:, 1], c=color , cmap=plt.cm.Spectral)
plt.xticks([]), plt.yticks([])
plt.title('Projected on PC-1 et PC2 (with color)')

ax = fig.add_subplot(133)
ax.scatter(X_projected_kpca[:, 0], X_projected_kpca[:, 1])
#plt.xticks([]), plt.yticks([])
plt.title('Projected on PC-1 et PC2 (without color)')
ax.set_xlabel("PC-1")
ax.set_ylabel("PC_2")

plt.show()

# %% [markdown]
# # === PCA comparison ===========================================

# %% [markdown]
# ## Prepare data (feature scaling)

# %%
from sklearn import preprocessing

# %%
std_scale = preprocessing.StandardScaler().fit(X)

# %%
X_scaled = std_scale.transform(X)

# %% [markdown]
# ## Apply PCA dimentionality reduction

# %%
from sklearn import decomposition

# %%
pca = decomposition.PCA(n_components=2)

# %% [markdown]
# #### Decompose

# %%
pca.fit(X_scaled)
# Out:
# PCA(n_components=2)

# %% [markdown]
# #### Examine explained variance

# %% [markdown]
# ...

# %% [markdown]
# #### Project

# %%
X_projected_pca = pca.transform(X_scaled)
X_projected_pca.shape
# Out:
# (5000, 2)

# %% [markdown]
# ## Plot

# %%
fig = plt.figure(figsize=(17,5))

ax = fig.add_subplot(131, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.Spectral)
ax.set_title("Original data")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")

ax = fig.add_subplot(132)
ax.scatter(X_projected_pca[:, 0], X_projected_pca[:, 1], c=color, cmap=plt.cm.Spectral)
plt.xticks([]), plt.yticks([])
plt.title('Projected data with color')

ax = fig.add_subplot(133)
ax.scatter(X_projected_pca[:, 0], X_projected_pca[:, 1])
#plt.xticks([]), plt.yticks([])
plt.title('Projected data without color')
ax.set_xlabel("PC-1")
ax.set_ylabel("PC_2")

plt.show()

# %% [markdown]
# ## --- Notes ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# PCA doesn't works well with non-linearly separable datasets...
#
# k-PCA doesn't seems useful on this kind of dataset.
#
# We should try with some other non-linear dataset...
